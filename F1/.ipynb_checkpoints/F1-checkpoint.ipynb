# %% [markdown]
# https://competitions.desights.ai/challenge/31

# %% [markdown]
# # Data Reading, Imports

# %%
#Set your Imports
import os
import sys
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import seaborn as sns
import matplotlib.transforms as mtrans
from summary import summary_summary

pd.set_option('display.float_format', lambda x: '%.4f' % x)

# Add the project root to sys.path
notebook_dir = os.path.dirname(os.path.abspath('F1.ipynb'))
project_root = os.path.abspath(os.path.join(notebook_dir, '..'))
if project_root not in sys.path:
    sys.path.append(notebook_dir)

races_dir = "races_2024/"
sing_qual_dir = "singapore_grand_prix_qualifyings_2018-2019-2022-2023/"
sing_races_dir = "singapore_grand_prix_races_2018-2019-2022-2023/"

# %%
skip = ["position_2O24.csv", "circuit_2024.csv"]

races = []
sing_qual = []
sing_races = []

with os.scandir(notebook_dir + "/" + races_dir) as it:
    for entry in it:
        if entry.name.endswith(".csv") and entry.is_file():
            if entry.name in skip:
                races.append((None, None))
                continue
            print(entry.name, entry.path)
            races.append((entry.name, pd.read_csv(entry.path)))

# with os.scandir(notebook_dir + "/" + sing_qual_dir) as it:
#     for entry in it:
#         if entry.name.endswith(".csv") and entry.is_file():
#             if entry.name in skip: continue
#             print(entry.name, entry.path)
#             sing_qual.append((entry.name, pd.read_csv(entry.path)))

# with os.scandir(notebook_dir + "/" + sing_races_dir) as it:
#     for entry in it:
#         if entry.name.endswith(".csv") and entry.is_file():
#             if entry.name in skip: continue
#             print(entry.name, entry.path)
#             sing_races.append((entry.name, pd.read_csv(entry.path)))
# Out:
# weather_2024.csv /home/ppc/Projects/Data-Science/F1/races_2024/weather_2024.csv
# control_message_2024.csv /home/ppc/Projects/Data-Science/F1/races_2024/control_message_2024.csv
# result_2024.csv /home/ppc/Projects/Data-Science/F1/races_2024/result_2024.csv
# circuit_2024.csv /home/ppc/Projects/Data-Science/F1/races_2024/circuit_2024.csv
# car_data_2024.csv /home/ppc/Projects/Data-Science/F1/races_2024/car_data_2024.csv
# session_status_2024.csv /home/ppc/Projects/Data-Science/F1/races_2024/session_status_2024.csv
# track_status_2024.csv /home/ppc/Projects/Data-Science/F1/races_2024/track_status_2024.csv
# lap_2024.csv /home/ppc/Projects/Data-Science/F1/races_2024/lap_2024.csv

# %%
# for l in [races, sing_qual, sing_races]:
#     for idx, df in enumerate(l):
#         print()
#         print("**" + df[0] + "**", idx, "\\")
#         print(' -- '.join(df[1].columns))

# %%
# races[1][1].iloc[50000:50020]
# races[6][1].head(20)
# races[8][1][races[8][1]["Driver"] == "VER"].iloc[0]

# %% [markdown]
# ## Columns & File descriptions

# %% [markdown]
# ### 2024

# %% [markdown]
# **weather_2024.csv** 0 \
# EventName -- Time -- AirTemp -- Humidity -- Pressure -- Rainfall -- TrackTemp -- WindDirection -- WindSpeed
#
# **position_2O24.csv** 1 \
# EventName -- DriverName -- Date -- Status -- X -- Y -- Z -- Source -- Time -- SessionTime
#
# **control_message_2024.csv** 2 \
# EventName -- Time -- Category -- Message -- Status -- Flag -- Scope -- Sector -- RacingNumber -- Lap
#
# **result_2024.csv** 3 \
# EventName -- DriverNumber -- BroadcastName -- Abbreviation -- DriverId -- TeamName -- TeamColor -- TeamId -- FirstName -- LastName -- FullName -- HeadshotUrl -- CountryCode -- Position -- ClassifiedPosition -- GridPosition -- Q1 -- Q2 -- Q3 -- Time -- Status -- Points
#
# **circuit_2024.csv** 4 \
# EventName -- TrackMarker -- X -- Y -- Number -- Letter -- Angle -- Distance
#
# **car_data_2024.csv** 5 \
# EventName -- DriverName -- Date -- RPM -- Speed -- nGear -- Throttle -- Brake -- DRS -- Source -- Time -- SessionTime
#
# **session_status_2024.csv** 6 \
# EventName -- Time -- Status
#
# **track_status_2024.csv** 7 \
# EventName -- Time -- Status -- Message
#
# **lap_2024.csv** 8 \
# EventName -- Time -- Driver -- DriverNumber -- LapTime -- LapNumber -- Stint -- PitOutTime -- PitInTime -- Sector1Time -- Sector2Time -- Sector3Time -- Sector1SessionTime -- Sector2SessionTime -- Sector3SessionTime -- SpeedI1 -- SpeedI2 -- SpeedFL -- SpeedST -- IsPersonalBest -- Compound -- TyreLife -- FreshTyre -- Team -- LapStartTime -- LapStartDate -- TrackStatus -- Position -- Deleted -- DeletedReason -- FastF1Generated -- IsAccurate

# %% [markdown]
# ### Singapore 2018-2023

# %% [markdown]
# **weather_singapore_grand_prix_2018-2019-2022-2023.csv** 0 \
# Year -- Time -- AirTemp -- Humidity -- Pressure -- Rainfall -- TrackTemp -- WindDirection -- WindSpeed
#
# **circuit_singapore_grand_prix_2018-2019-2022-2023.csv** 1 \
# Year -- TrackMarker -- X -- Y -- Number -- Letter -- Angle -- Distance
#
# **position_singapore_grand_prix_2018-2019-2022-2023.csv** 2 \
# Year -- DriverName -- Date -- Status -- X -- Y -- Z -- Source -- Time -- SessionTime
#
# **car_data_singapore_grand_prix_2018-2019-2022-2023.csv** 3 \
# Year -- DriverName -- Date -- RPM -- Speed -- nGear -- Throttle -- Brake -- DRS -- Source -- Time -- SessionTime
#
# **lap_singapore_grand_prix_2018-2019-2022-2023.csv** 4 \
# Year -- Time -- Driver -- DriverNumber -- LapTime -- LapNumber -- Stint -- PitOutTime -- PitInTime -- Sector1Time -- Sector2Time -- Sector3Time -- Sector1SessionTime -- Sector2SessionTime -- Sector3SessionTime -- SpeedI1 -- SpeedI2 -- SpeedFL -- SpeedST -- IsPersonalBest -- Compound -- TyreLife -- FreshTyre -- Team -- LapStartTime -- LapStartDate -- TrackStatus -- Position -- Deleted -- DeletedReason -- FastF1Generated -- IsAccurate
#
# **track_status_singapore_grand_prix_2018-2019-2022-2023.csv** 5 \
# Year -- Time -- Status -- Message
#
# **result_singapore_grand_prix_2018-2019-2022-2023.csv** 6 \
# Year -- DriverNumber -- BroadcastName -- Abbreviation -- DriverId -- TeamName -- TeamColor -- TeamId -- FirstName -- LastName -- FullName -- HeadshotUrl -- CountryCode -- Position -- ClassifiedPosition -- GridPosition -- Q1 -- Q2 -- Q3 -- Time -- Status -- Points
#
# **session_status_singapore_grand_prix_2018-2019-2022-2023.csv** 7 \
# Year -- Time -- Status
#
# **control_message_singapore_grand_prix_2018-2019-2022-2023.csv** 8 \
# Year -- Time -- Category -- Message -- Status -- Flag -- Scope -- Sector -- RacingNumber -- Lap
#
# **weather_singapore_grand_prix_2018-2019-2022-2023.csv** 0 \
# Year -- Time -- AirTemp -- Humidity -- Pressure -- Rainfall -- TrackTemp -- WindDirection -- WindSpeed
#
# **circuit_singapore_grand_prix_2018-2019-2022-2023.csv** 1 \
# Year -- TrackMarker -- X -- Y -- Number -- Letter -- Angle -- Distance
#
# **position_singapore_grand_prix_2018-2019-2022-2023.csv** 2 \
# Year -- DriverName -- Date -- Status -- X -- Y -- Z -- Source -- Time -- SessionTime
#
# **car_data_singapore_grand_prix_2018-2019-2022-2023.csv** 3 \
# Year -- DriverName -- Date -- RPM -- Speed -- nGear -- Throttle -- Brake -- DRS -- Source -- Time -- SessionTime
#
# **lap_singapore_grand_prix_2018-2019-2022-2023.csv** 4 \
# Year -- Time -- Driver -- DriverNumber -- LapTime -- LapNumber -- Stint -- PitOutTime -- PitInTime -- Sector1Time -- Sector2Time -- Sector3Time -- Sector1SessionTime -- Sector2SessionTime -- Sector3SessionTime -- SpeedI1 -- SpeedI2 -- SpeedFL -- SpeedST -- IsPersonalBest -- Compound -- TyreLife -- FreshTyre -- Team -- LapStartTime -- LapStartDate -- TrackStatus -- Position -- Deleted -- DeletedReason -- FastF1Generated -- IsAccurate
#
# **track_status_singapore_grand_prix_2018-2019-2022-2023.csv** 5 \
# Year -- Time -- Status -- Message
#
# **result_singapore_grand_prix_2018-2019-2022-2023.csv** 6 \
# Year -- DriverNumber -- BroadcastName -- Abbreviation -- DriverId -- TeamName -- TeamColor -- TeamId -- FirstName -- LastName -- FullName -- HeadshotUrl -- CountryCode -- Position -- ClassifiedPosition -- GridPosition -- Q1 -- Q2 -- Q3 -- Time -- Status -- Points
#
# **session_status_singapore_grand_prix_2018-2019-2022-2023.csv** 7 \
# Year -- Time -- Status
#
# **control_message_singapore_grand_prix_2018-2019-2022-2023.csv** 8 \
# Year -- Time -- Category -- Message -- Status -- Flag -- Scope -- Sector -- RacingNumber -- Lap

# %% [markdown]
# # Data Cleaning

# %%
summary_summary(races[8][1])
# Out:
#                     unique   null   dtypes  dupe outliers  count     mean  \
# Deleted                  2      0     bool     0
# FastF1Generated          2      0     bool     0
# FreshTyre                2      0     bool     0
# IsAccurate               2      0     bool     0
# TrackStatus             21      0    int64     0      135  17123   6.3227
# DriverNumber            21      0    int64     0        0  17123  27.7856
# TyreLife                78      0  float64     0      167  17123  14.8040
# Position                20     15  float64     0        0  17108   9.9174
# SpeedFL                221    571  float64     0      146  16552 268.8545
# SpeedI1                262   2759  float64     0      132  14364 256.4988
# SpeedI2                249     16  float64     0      152  17107 248.0724
# SpeedST                261   1290  float64     0      138  15833 296.2321
# Stint                    5      0  float64     0      137  17123   2.0960
# LapNumber               78      0  float64     0      151  17123  31.1761
# Sector3SessionTime   17068     40   object     0
# Sector3Time          10003     40   object     0
# Team                    10      0   object     0
# Time                 17097      0   object     0
# Sector2Time          10662     17   object     0
# Compound                 5      0   object     0
# Sector1Time           9847    335   object     0
# Sector1SessionTime   16734    373   object     0
# PitInTime              556  16567   object     0
# LapTime              13266    113   object     0
# LapStartTime         16797      0   object     0
# LapStartDate         16808      8   object     0
# IsPersonalBest           2      8   object     0
# EventName               15      0   object     0
# Driver                  21      0   object     0
# DeletedReason          150  16950   object     0
# Sector2SessionTime   17086     17   object     0
# PitOutTime             554  16569   object     0
#
#                        std     min       max
# Deleted
# FastF1Generated
# FreshTyre
# IsAccurate
# TrackStatus        63.4643  1.0000 2671.0000
# DriverNumber       23.9351  1.0000   81.0000
# TyreLife           11.8374  1.0000   78.0000
# Position            5.5015  1.0000   20.0000
# SpeedFL            26.2710  1.0000  330.0000
# SpeedI1            41.5246 65.0000  357.0000
# SpeedI2            40.0180 57.0000  336.0000
# SpeedST            27.2427 65.0000  355.0000
# Stint               0.8618  1.0000    5.0000
# LapNumber          18.6523  1.0000   78.0000
# Sector3SessionTime
# Sector3Time
# Team
# Time
# Sector2Time
# Compound
# Sector1Time
# Sector1SessionTime
# PitInTime
# LapTime
# LapStartTime
# LapStartDate
# IsPersonalBest
# EventName
# Driver
# DeletedReason
# Sector2SessionTime
# PitOutTime

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Explore the data thoroughly, uncovering key patterns and insights that can inform race strategies. For each team and driver, analyze the following and support your findings with relevant visuals:

# %% [markdown]
# ## Total Number of Pit Stops
# For each driver and team in each race of the 2024 F1 season, determine the total number of pit stops made. Identify any patterns or trends in pit stop frequency.
#
# https://www.formula1.com/en/results/2024/races/1231/australia/race-result \
# https://www.formula1.com/en/video/race-highlights-2024-australian-grand-prix.1794387578890217636

# %% [markdown]
# * Read laps data
# * Read results data
#     * Merge laps (lefton: EventName, Driver) with results (righton:EventName, Abbreviation, data: ClassifiedPosition)
# * Filter out drivers where pos == "R"
#
#
#
# * Establish base df pitstops_df
#     *  Grab PIT || POT not null, sort by Driver / Event Name / Time
# * Calculate Total number of pit stops per individual
#     * Groupby Event & Driver - select Event/Driver/PitInTime != null - agg count
#     * Each Event/Driver will have a number, call it PitStopsPerIndividual
#         * Merge pitstops_df on this new frame (lefton: Event/Driver, righton: Event/Driver)
# * Calculate Delta between lap times
#     * Should just be that timediff thing pandas has
# * Calculate Delta between lap numbers
#     * Same thing
# * Calculate Pit Time Delta
#     * Same thing
#
# * Team pit stops, Total
#     * Pit Stop Data - Group by Team, select Team/Driver/EventName/PitStopsPerIndividual - sum that group
# * Driver pit stops, Total
#     * Pit Stop Data - Group by Driver, select Driver/EventName/PitStopsPerIndividual - sum that group
# * Per race (for loop through races)
#     * Team pit stops, bar chart
#         * Pit Stop Data - Groupby Team - select Team/Driver/PitStopsPerIndividual - sum that group
#         * Team1 XXXXXXXX
#         * Team2 XXXXXX
#         * Team3 XXXXXXXXXXXX
#     * Driver pit stops, bar chart
#         * Pit Stop Data - Groupby Driver - select Driver/PitStopsPerIndividual - sum that group (probably no gb needed)
#         * Same as above
# * Patterns and trends in pit stop frequency
#     * Grab PIT || POT not null, sort by Driver / Event Name / Time
#     * Lap Number Delta - find avg laps between pit stops
#     * Pit Time Delta - find avg time between pit stops
#     * Lap Time Delta - find avg time between laps w/ pit stops. Compare to pit time delta

# %%
# Here's an example of VER DNF on this particular race - ClassifiedPosition = "R"
races[3][1][races[3][1]["EventName"] == "Australian Grand Prix"].tail(5)

# %%
# PitInTime / PitOutTime != Null
races[8][1][races[8][1]["Driver"] == "VER"][(races[8][1]["PitInTime"].notna()) | (races[8][1]["PitOutTime"].notna())] \
    [["Time", "EventName", "Driver", "Team", "LapTime", "LapNumber", "Stint", "PitInTime", "PitOutTime", "Compound"]].sort_values(["EventName", "Time"]).head(30)
# Out:
#                          Time                  EventName Driver  \
# 2033   0 days 01:04:24.613000      Australian Grand Prix    VER
# 11441  0 days 01:22:42.731000        Austrian Grand Prix    VER
# 11442  0 days 01:24:10.125000        Austrian Grand Prix    VER
# 11469  0 days 01:55:46.519000        Austrian Grand Prix    VER
# 11470  0 days 01:57:18.104000        Austrian Grand Prix    VER
# 11482  0 days 02:11:39.650000        Austrian Grand Prix    VER
# 11483  0 days 02:13:13.347000        Austrian Grand Prix    VER
# 16     0 days 01:27:31.985000         Bahrain Grand Prix    VER
# 17     0 days 01:29:29.839000         Bahrain Grand Prix    VER
# 36     0 days 01:59:49.512000         Bahrain Grand Prix    VER
# 37     0 days 02:01:45.957000         Bahrain Grand Prix    VER
# 14997  0 days 01:13:48.023000         Belgian Grand Prix    VER
# 14998  0 days 01:15:50.812000         Belgian Grand Prix    VER
# 15015  0 days 01:46:37.138000         Belgian Grand Prix    VER
# 15016  0 days 01:48:37.627000         Belgian Grand Prix    VER
# 12617  0 days 01:38:50.571000         British Grand Prix    VER
# 12618  0 days 01:40:49.740000         British Grand Prix    VER
# 12629  0 days 01:59:23.982000         British Grand Prix    VER
# 12630  0 days 02:01:22.293000         British Grand Prix    VER
# 8577   0 days 00:42:09.266000        Canadian Grand Prix    VER
# 8578   0 days 00:43:59.115000        Canadian Grand Prix    VER
# 8597   0 days 01:13:46.176000        Canadian Grand Prix    VER
# 8598   0 days 01:15:16.999000        Canadian Grand Prix    VER
# 3947   0 days 01:17:17.305000         Chinese Grand Prix    VER
# 3948   0 days 01:19:16.379000         Chinese Grand Prix    VER
# 3957   0 days 01:35:28.488000         Chinese Grand Prix    VER
# 3958   0 days 01:38:14.797000         Chinese Grand Prix    VER
# 15795  0 days 01:32:04.790000           Dutch Grand Prix    VER
# 15796  0 days 01:33:39.364000           Dutch Grand Prix    VER
# 6101   0 days 01:28:11.068000  Emilia Romagna Grand Prix    VER
#
#                   Team                 LapTime  LapNumber  Stint  \
# 2033   Red Bull Racing                     NaN     4.0000 1.0000
# 11441  Red Bull Racing  0 days 00:01:14.679000    23.0000 1.0000
# 11442  Red Bull Racing  0 days 00:01:27.394000    24.0000 2.0000
# 11469  Red Bull Racing  0 days 00:01:13.860000    51.0000 2.0000
# 11470  Red Bull Racing  0 days 00:01:31.585000    52.0000 3.0000
# 11482  Red Bull Racing  0 days 00:01:38.003000    64.0000 3.0000
# 11483  Red Bull Racing  0 days 00:01:33.697000    65.0000 4.0000
# 16     Red Bull Racing  0 days 00:01:39.896000    17.0000 1.0000
# 17     Red Bull Racing  0 days 00:01:57.854000    18.0000 2.0000
# 36     Red Bull Racing  0 days 00:01:39.234000    37.0000 2.0000
# 37     Red Bull Racing  0 days 00:01:56.445000    38.0000 3.0000
# 14997  Red Bull Racing  0 days 00:01:54.655000    10.0000 1.0000
# 14998  Red Bull Racing  0 days 00:02:02.789000    11.0000 2.0000
# 15015  Red Bull Racing  0 days 00:01:52.026000    28.0000 2.0000
# 15016  Red Bull Racing  0 days 00:02:00.489000    29.0000 3.0000
# 12617  Red Bull Racing  0 days 00:01:41.491000    26.0000 1.0000
# 12618  Red Bull Racing  0 days 00:01:59.169000    27.0000 2.0000
# 12629  Red Bull Racing  0 days 00:01:35.963000    38.0000 2.0000
# 12630  Red Bull Racing  0 days 00:01:58.311000    39.0000 3.0000
# 8577   Red Bull Racing  0 days 00:01:53.896000    25.0000 1.0000
# 8578   Red Bull Racing  0 days 00:01:49.849000    26.0000 2.0000
# 8597   Red Bull Racing  0 days 00:01:40.612000    45.0000 2.0000
# 8598   Red Bull Racing  0 days 00:01:30.823000    46.0000 3.0000
# 3947   Red Bull Racing  0 days 00:01:46.526000    13.0000 1.0000
# 3948   Red Bull Racing  0 days 00:01:59.074000    14.0000 2.0000
# 3957   Red Bull Racing  0 days 00:02:17.938000    23.0000 2.0000
# 3958   Red Bull Racing                     NaN    24.0000 3.0000
# 15795  Red Bull Racing  0 days 00:01:19.890000    27.0000 1.0000
# 15796  Red Bull Racing  0 days 00:01:34.574000    28.0000 2.0000
# 6101   Red Bull Racing  0 days 00:01:26.212000    24.0000 1.0000
#
#                     PitInTime              PitOutTime      Compound
# 2033   0 days 01:04:24.613000                     NaN        MEDIUM
# 11441  0 days 01:22:39.342000                     NaN        MEDIUM
# 11442                     NaN  0 days 01:23:01.443000          HARD
# 11469  0 days 01:55:43.269000                     NaN          HARD
# 11470                     NaN  0 days 01:56:09.187000        MEDIUM
# 11482  0 days 02:11:36.305000                     NaN        MEDIUM
# 11483                     NaN  0 days 02:11:59.048000          SOFT
# 16     0 days 01:27:30.291000                     NaN          SOFT
# 17                        NaN  0 days 01:27:55.379000          HARD
# 36     0 days 01:59:47.796000                     NaN          HARD
# 37                        NaN  0 days 02:00:12.014000          SOFT
# 14997  0 days 01:13:44.188000                     NaN        MEDIUM
# 14998                     NaN  0 days 01:14:07.325000          HARD
# 15015  0 days 01:46:33.171000                     NaN          HARD
# 15016                     NaN  0 days 01:46:56.099000        MEDIUM
# 12617  0 days 01:38:44.599000                     NaN        MEDIUM
# 12618                     NaN  0 days 01:39:13.065000  INTERMEDIATE
# 12629  0 days 01:59:18.092000                     NaN  INTERMEDIATE
# 12630                     NaN  0 days 01:59:47.248000          HARD
# 8577   0 days 00:41:46.553000                     NaN  INTERMEDIATE
# 8578                      NaN  0 days 00:42:10.800000  INTERMEDIATE
# 8597   0 days 01:13:23.616000                     NaN  INTERMEDIATE
# 8598                      NaN  0 days 01:13:47.784000        MEDIUM
# 3947   0 days 01:17:15.520000                     NaN        MEDIUM
# 3948                      NaN  0 days 01:17:38.092000          HARD
# 3957   0 days 01:35:26.720000                     NaN          HARD
# 3958                      NaN  0 days 01:35:48.943000          HARD
# 15795  0 days 01:32:03.252000                     NaN        MEDIUM
# 15796                     NaN  0 days 01:32:24.001000          HARD
# 6101   0 days 01:28:06.696000                     NaN        MEDIUM

# %%
# Slice of some laps before and after a pit stop
races[8][1].iloc[11464:11474][["Time", "EventName", "Driver", "Team", "LapTime", "LapNumber", "Stint", "PitInTime", "PitOutTime", "Compound"]].sort_values(["EventName", "Time"])
# Out:
#                          Time            EventName Driver             Team  \
# 11464  0 days 01:49:50.360000  Austrian Grand Prix    VER  Red Bull Racing
# 11465  0 days 01:51:01.018000  Austrian Grand Prix    VER  Red Bull Racing
# 11466  0 days 01:52:11.378000  Austrian Grand Prix    VER  Red Bull Racing
# 11467  0 days 01:53:21.921000  Austrian Grand Prix    VER  Red Bull Racing
# 11468  0 days 01:54:32.659000  Austrian Grand Prix    VER  Red Bull Racing
# 11469  0 days 01:55:46.519000  Austrian Grand Prix    VER  Red Bull Racing
# 11470  0 days 01:57:18.104000  Austrian Grand Prix    VER  Red Bull Racing
# 11471  0 days 01:58:26.876000  Austrian Grand Prix    VER  Red Bull Racing
# 11472  0 days 01:59:35.665000  Austrian Grand Prix    VER  Red Bull Racing
# 11473  0 days 02:00:44.878000  Austrian Grand Prix    VER  Red Bull Racing
#
#                       LapTime  LapNumber  Stint               PitInTime  \
# 11464  0 days 00:01:10.288000    46.0000 2.0000                     NaN
# 11465  0 days 00:01:10.658000    47.0000 2.0000                     NaN
# 11466  0 days 00:01:10.360000    48.0000 2.0000                     NaN
# 11467  0 days 00:01:10.543000    49.0000 2.0000                     NaN
# 11468  0 days 00:01:10.738000    50.0000 2.0000                     NaN
# 11469  0 days 00:01:13.860000    51.0000 2.0000  0 days 01:55:43.269000
# 11470  0 days 00:01:31.585000    52.0000 3.0000                     NaN
# 11471  0 days 00:01:08.772000    53.0000 3.0000                     NaN
# 11472  0 days 00:01:08.789000    54.0000 3.0000                     NaN
# 11473  0 days 00:01:09.213000    55.0000 3.0000                     NaN
#
#                    PitOutTime Compound
# 11464                     NaN     HARD
# 11465                     NaN     HARD
# 11466                     NaN     HARD
# 11467                     NaN     HARD
# 11468                     NaN     HARD
# 11469                     NaN     HARD
# 11470  0 days 01:56:09.187000   MEDIUM
# 11471                     NaN   MEDIUM
# 11472                     NaN   MEDIUM
# 11473                     NaN   MEDIUM

# %%
races[8][1].iloc[11478:11487][["Time", "EventName", "Driver", "Team", "LapTime", "LapNumber", "Stint", "PitInTime", "PitOutTime", "Compound"]].sort_values(["EventName", "Time"])
# Out:
#                          Time            EventName Driver             Team  \
# 11478  0 days 02:06:31.704000  Austrian Grand Prix    VER  Red Bull Racing
# 11479  0 days 02:07:41.707000  Austrian Grand Prix    VER  Red Bull Racing
# 11480  0 days 02:08:51.235000  Austrian Grand Prix    VER  Red Bull Racing
# 11481  0 days 02:10:01.647000  Austrian Grand Prix    VER  Red Bull Racing
# 11482  0 days 02:11:39.650000  Austrian Grand Prix    VER  Red Bull Racing
# 11483  0 days 02:13:13.347000  Austrian Grand Prix    VER  Red Bull Racing
# 11484  0 days 02:14:37.066000  Austrian Grand Prix    VER  Red Bull Racing
# 11485  0 days 02:15:48.757000  Austrian Grand Prix    VER  Red Bull Racing
# 11486  0 days 02:16:56.476000  Austrian Grand Prix    VER  Red Bull Racing
#
#                       LapTime  LapNumber  Stint               PitInTime  \
# 11478  0 days 00:01:09.399000    60.0000 3.0000                     NaN
# 11479  0 days 00:01:10.003000    61.0000 3.0000                     NaN
# 11480  0 days 00:01:09.528000    62.0000 3.0000                     NaN
# 11481  0 days 00:01:10.412000    63.0000 3.0000                     NaN
# 11482  0 days 00:01:38.003000    64.0000 3.0000  0 days 02:11:36.305000
# 11483  0 days 00:01:33.697000    65.0000 4.0000                     NaN
# 11484  0 days 00:01:23.719000    66.0000 4.0000                     NaN
# 11485  0 days 00:01:11.691000    67.0000 4.0000                     NaN
# 11486  0 days 00:01:07.719000    68.0000 4.0000                     NaN
#
#                    PitOutTime Compound
# 11478                     NaN   MEDIUM
# 11479                     NaN   MEDIUM
# 11480                     NaN   MEDIUM
# 11481                     NaN   MEDIUM
# 11482                     NaN   MEDIUM
# 11483  0 days 02:11:59.048000     SOFT
# 11484                     NaN     SOFT
# 11485                     NaN     SOFT
# 11486                     NaN     SOFT

# %%
races[8][1].iloc[9]
# Out:
# EventName                  Bahrain Grand Prix
# Time                   0 days 01:16:09.722000
# Driver                                    VER
# DriverNumber                                1
# LapTime                0 days 00:01:36.960000
# LapNumber                             10.0000
# Stint                                  1.0000
# PitOutTime                                NaN
# PitInTime                                 NaN
# Sector1Time            0 days 00:00:30.986000
# Sector2Time            0 days 00:00:42.009000
# Sector3Time            0 days 00:00:23.965000
# Sector1SessionTime     0 days 01:15:03.748000
# Sector2SessionTime     0 days 01:15:45.757000
# Sector3SessionTime     0 days 01:16:09.722000
# SpeedI1                              232.0000
# SpeedI2                              244.0000
# SpeedFL                              277.0000
# SpeedST                              293.0000
# IsPersonalBest                          False
# Compound                                 SOFT
# TyreLife                              13.0000
# FreshTyre                               False
# Team                          Red Bull Racing
# LapStartTime           0 days 01:14:32.762000
# LapStartDate          2024-03-02 15:18:15.193
# TrackStatus                                12
# Position                               1.0000
# Deleted                                 False
# DeletedReason                             NaN
# FastF1Generated                         False
# IsAccurate                               True
# Name: 9, dtype: object

# %% [markdown]
# ## Tire Compounds Used During the Race
# Identify the tire compounds used by each driver in every race. Create visualizations to compare the tire compound strategies across different teams and drivers.

# %% [markdown]
# * Team Tire compositions, Total (# of laps used with a type of tire)
#     * Laps data - group by Team - select Team/Event/Driver/LapValue/Compound - Val Count Graph of Compound
# * Driver Tire compositions, Total (# of laps used with a type of tire)
#     * Laps data - group by Driver - select Driver/Event/LapValue/Compound - Value count Graph of Compound
# * Per Race (for loop through races)
#     * Team Tire compositions, horizontal stacked bar graph
#         * Laps data - group by Team - Select Team/Driver/LapCount/Compound - Value count of Compound
#         * Team1 XXXyyyyyyyyZZZZ
#         * Team2 XXXXXXyyyyZZZZZ
#     * Driver Tire compositions, horizontal stacked bar graph
#         * Laps data - group by Driver - select Driver/LapCount/Compound - Value count of Compound
#         * Driver1 XXXyyyyyyyZZZZ
#         * Driver2 XyyyyyyZZZZZZZ

# %%
races[8][1].iloc[0]
# Out:
# EventName                  Bahrain Grand Prix
# Time                   0 days 01:01:37.510000
# Driver                                    VER
# DriverNumber                                1
# LapTime                0 days 00:01:37.284000
# LapNumber                              1.0000
# Stint                                  1.0000
# PitOutTime                                NaN
# PitInTime                                 NaN
# Sector1Time                               NaN
# Sector2Time            0 days 00:00:41.266000
# Sector3Time            0 days 00:00:23.616000
# Sector1SessionTime                        NaN
# Sector2SessionTime     0 days 01:01:13.987000
# Sector3SessionTime     0 days 01:01:37.669000
# SpeedI1                              234.0000
# SpeedI2                              250.0000
# SpeedFL                              276.0000
# SpeedST                              251.0000
# IsPersonalBest                          False
# Compound                                 SOFT
# TyreLife                               4.0000
# FreshTyre                               False
# Team                          Red Bull Racing
# LapStartTime           0 days 00:59:59.911000
# LapStartDate          2024-03-02 15:03:42.342
# TrackStatus                                12
# Position                               1.0000
# Deleted                                 False
# DeletedReason                             NaN
# FastF1Generated                         False
# IsAccurate                              False
# Name: 0, dtype: object

# %% [markdown]
# ## Number of Laps Completed on Each Tire Compound
# Analyze the number of laps completed by each driver on each tire compound during their stints. Use visuals to illustrate the relationship between stint length and tire compound usage.

# %% [markdown]
# ## Average Lap Time per Stint and Delta Time per Tire Compound
# Calculate the average lap time for each stint. Visualize the changes in lap times within each stint to understand how tire performance evolved over the course of a race.

# %% [markdown]
# ## Time Spent in Pits
# Measure the total time spent in the pits by each driver during the races. Create visual representations to show how pit time varies across drivers and teams.
